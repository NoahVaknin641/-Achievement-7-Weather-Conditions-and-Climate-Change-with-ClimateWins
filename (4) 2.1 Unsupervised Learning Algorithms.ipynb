# %% [markdown]
# # (4) 2.1: Unsupervised Learning Algorithms

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.
# %matplotlib inline

# Turning off warning feature
import warnings
warnings.filterwarnings('ignore')

# Suppress scientific notation for easier analysis profiling
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
path = r'C:\Users\nvak6\Machine Learning with Python'
dfPCA = pd.read_csv(os.path.join(path,'PCA1.csv'))

# %%
dfPCA2 = pd.read_csv(os.path.join(path, 'PCA2.csv'))

# %%
# Perform linkage for the single method with PCA data
distance_single_pca = linkage(dfPCA, method="single")

# Create the figure for the dendrogram
plt.figure(figsize=(18,6))

# Generate the dendrogram
dendrogram(distance_single_pca, leaf_rotation=90)

# Label the axes
plt.xlabel('Index')
plt.ylabel('Distance')

# Set the title
plt.suptitle("VALENTIA - Dendrogram Single Method (PCA)", fontsize=18)

# Specify the path and file name
output_file = r'C:\Users\nvak6\Machine Learning with Python\VALENTIA - Dendrogram Single Method (PCA).png'

# Save the plot as a PNG file at the specified location
plt.savefig(output_file)

# Display the plot
plt.show()

# %%
# Perform linkage for the complete method with PCA data
distance_complete_pca = linkage(dfPCA, method="complete")

# Create the figure for the dendrogram
plt.figure(figsize=(18,6))

# Generate the dendrogram
dendrogram(distance_complete_pca, leaf_rotation=90)

# Label the axes
plt.xlabel('Index')
plt.ylabel('Distance')

# Set the title
plt.suptitle("VALENTIA - Dendrogram Complete Method (PCA)", fontsize=18)

# Specify the path and file name
output_file = r'C:\Users\nvak6\Machine Learning with Python\VALENTIA - Dendrogram Complete Method (PCA).png'

# Save the plot as a PNG file at the specified location
plt.savefig(output_file)

# Display the plot
plt.show()

# %%
# Perform linkage for the average method with PCA data
distance_average_pca = linkage(dfPCA, method="average")

# Create the figure for the dendrogram
plt.figure(figsize=(18,6))

# Generate the dendrogram
dendrogram(distance_average_pca, leaf_rotation=90)

# Label the axes
plt.xlabel('Index')
plt.ylabel('Distance')

# Set the title
plt.suptitle("VALENTIA - Dendrogram Average Method (PCA)", fontsize=18)

# Specify the path and file name
output_file = r'C:\Users\nvak6\Machine Learning with Python\VALENTIA - Dendrogram Average Method (PCA).png'

# Save the plot as a PNG file at the specified location
plt.savefig(output_file)

# Display the plot
plt.show()

# %%
# Perform linkage for the Ward method with PCA data
distance_ward = linkage(dfPCA, method="ward")

# Create the figure for the dendrogram
plt.figure(figsize=(18,6))

# Generate the dendrogram
dendrogram(distance_ward, leaf_rotation=90)

# Label the axes
plt.xlabel('Index')
plt.ylabel('Distance')

# Set the title
plt.suptitle("VALENTIA - Dendrogram Ward Method (PCA)", fontsize=18)

# Specify the path and file name
output_file = r'C:\Users\nvak6\Machine Learning with Python\VALENTIA - Dendrogram Ward Method (PCA).png'

# Save the plot as a PNG file at the specified location
plt.savefig(output_file)

# Display the plot
plt.show()

# %%
# Perform linkage for the Single method with PCA2 data
distance_single_pca2 = linkage(dfPCA2, method="single")

# Create the figure for the dendrogram
plt.figure(figsize=(18,6))

# Generate the dendrogram
dendrogram(distance_single_pca2, leaf_rotation=90)

# Label the axes
plt.xlabel('Index')
plt.ylabel('Distance')

# Set the title
plt.suptitle("VALENTIA - Dendrogram Single Method (PCA2)", fontsize=18)

# Specify the path and file name
output_file = r'C:\Users\nvak6\Machine Learning with Python\VALENTIA - Dendrogram Single Method (PCA2).png'

# Save the plot as a PNG file at the specified location
plt.savefig(output_file)

# Display the plot
plt.show()

# %%
# Perform linkage for the Complete method with PCA2 data
distance_complete_pca2 = linkage(dfPCA2, method="complete")

# Create the figure for the dendrogram
plt.figure(figsize=(18,6))

# Generate the dendrogram
dendrogram(distance_complete_pca2, leaf_rotation=90)

# Label the axes
plt.xlabel('Index')
plt.ylabel('Distance')

# Set the title
plt.suptitle("VALENTIA - Dendrogram Complete Method (PCA2)", fontsize=18)

# Specify the path and file name
output_file = r'C:\Users\nvak6\Machine Learning with Python\VALENTIA - Dendrogram Complete Method (PCA2).png'

# Save the plot as a PNG file at the specified location
plt.savefig(output_file)

# Display the plot
plt.show()

# %%
distance_average_pca2 = linkage(dfPCA2, method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_average_pca2, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Average Method (PCA2)", fontsize=18)

# Specify the path and file name
output_file = r"C:\Users\nvak6\Machine Learning with Python\VALENTIA - Dendrogram average Method (PCA2).png"

# Save the plot as a PNG file at the specified location
plt.savefig(output_file)

# Display the plot
plt.show()

# %%
distance_ward2 = linkage(dfPCA2, method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_ward2, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Ward Method (PCA2)", fontsize=18)

# Specify the path and file name
output_file = r"C:\Users\nvak6\Machine Learning with Python\VALENTIA - Dendrogram Ward Method (PCA2).png"

# Save the plot as a PNG file at the specified location
plt.savefig(output_file)

# Display the plot
plt.show()
